# %% [markdown]
# # Importing Header, SoilPrep, and PlotFunctions

# %%
import import_ipynb 
from Header import *

import import_ipynb
from SoilPrep import *
# Out:
# importing Jupyter notebook from Header.ipynb
# importing Jupyter notebook from SoilPrep.ipynb

# %%
import import_ipynb
from PlotFunctions import *
# Out:
# importing Jupyter notebook from PlotFunctions.ipynb
# importing Jupyter notebook from LoadDataMetaData.ipynb

# %%
import import_ipynb
from HyperMainVenus import *
# Out:
# importing Jupyter notebook from HyperMainVenus.ipynb
# Type of fod_sampled11: <class 'pandas.core.frame.DataFrame'>
# For:Sand-> ['L1r2', 0.22, 'Spec:', 'none', 'bands: 11'] :mult
# For:Sand-> ['L1r2', 0.26, 'Spec:', 'fod_log', 'bands: 11'] :plsr
# For:Sand-> ['L1r2', 0.17, 'Spec:', 'log', 'bands: 11'] :svr
# For:Sand-> ['L1r2', -0.14, 'Spec:', 'fod', 'bands: 11'] :ridge
# For:Sand-> ['L1r2', 0.31, 'Spec:', 'none', 'bands: 11'] :cubist
# For:Sand-> ['L1r2', 0.32, 'Spec:', 'fod', 'bands: 11'] :gbrt
# For:Silt-> ['L1r2', 0.16, 'Spec:', 'fod', 'bands: 11'] :mult
# For:Silt-> ['L1r2', 0.19, 'Spec:', 'none', 'bands: 11'] :plsr
# For:Silt-> ['L1r2', 0.1, 'Spec:', 'fod_log', 'bands: 11'] :svr
# For:Silt-> ['L1r2', 0.18, 'Spec:', 'log', 'bands: 11'] :ridge
# For:Silt-> ['L1r2', 0.21, 'Spec:', 'fod', 'bands: 11'] :cubist
# For:Silt-> ['L1r2', 0.08, 'Spec:', 'fod_log', 'bands: 11'] :gbrt
# For:Clay-> ['L1r2', 0.25, 'Spec:', 'fod_log', 'bands: 11'] :mult
# For:Clay-> ['L1r2', 0.25, 'Spec:', 'fod_log', 'bands: 11'] :plsr
# For:Clay-> ['L1r2', -0.08, 'Spec:', 'log', 'bands: 11'] :svr
# For:Clay-> ['L1r2', 0.26, 'Spec:', 'fod_log', 'bands: 11'] :ridge
# For:Clay-> ['L1r2', 0.25, 'Spec:', 'log', 'bands: 11'] :cubist
# For:Clay-> ['L1r2', 0.22, 'Spec:', 'fod_cr', 'bands: 11'] :gbrt
# For:TOC-> ['L1r2', 0.33, 'Spec:', 'fod_log', 'bands: 11'] :mult
# For:TOC-> ['L1r2', 0.39, 'Spec:', 'fod_log', 'bands: 11'] :plsr
# For:TOC-> ['L1r2', 0.42, 'Spec:', 'log', 'bands: 11'] :svr
# For:TOC-> ['L1r2', 0.4, 'Spec:', 'fod_log', 'bands: 11'] :ridge
# For:TOC-> ['L1r2', 0.35, 'Spec:', 'fod', 'bands: 11'] :cubist
# For:TOC-> ['L1r2', 0.25, 'Spec:', 'fod', 'bands: 11'] :gbrt
# interactive(children=(Dropdown(description='method', options=('mult', 'plsr', 'svr', 'ridge', 'cubist', 'gbrt'…

# %% [markdown]
# ## Loading  Mtree

# %%
import pandas as pd

HMtree = pd.read_pickle('HMtreeVen.pickle')

# %%
# with open ('Feature.pickle', 'rb') as file:
#     feature_scores = pickle.load(file)

# %%
# with open ('Models.pickle', 'rb') as file:
#     model_details = pickle.load(file)

# %% [markdown]
#  #  Best Models for Sand, Silt, Clay, and TOC.

# %%
feature_scores = {}

model_details ={}

# %%
#HMtree['svr']['TOC']['none']['log']

# %% [markdown]
# ##  Sand

# %% [markdown]
# ### GBRT

# %% [markdown]
# Sand -> [ r2 - **0.32**, Spec - fod, n_bands -11]     <br/><br/>
# ***Description***: To obtain the best model for sand using gbrt method we trained the model on the first order derivative of the  smoothed spectra which was  resampled to the 11 bands provided by Venus.

# %%
# Check the shape of the DataFrame
print("Shape of fod_sampled11:", fod_sampled11.shape)

# Check the data types of each column
print("Data types of fod_sampled11:\n", fod_sampled11.dtypes)

# Check for missing values
print("Missing values in fod_sampled11:\n", fod_sampled11.isnull().sum())

# Display the first few rows of the DataFrame
print("First few rows of fod_sampled11:\n", fod_sampled11.head())
# Out:
# Shape of fod_sampled11: (294, 11)
# Data types of fod_sampled11:
#  420    float64
# 443    float64
# 490    float64
# 555    float64
# 638    float64
# 672    float64
# 702    float64
# 742    float64
# 782    float64
# 865    float64
# 910    float64
# dtype: object
# Missing values in fod_sampled11:
#  420    0
# 443    0
# 490    0
# 555    0
# 638    0
# 672    0
# 702    0
# 742    0
# 782    0
# 865    0
# 910    0
# dtype: int64
# First few rows of fod_sampled11:
#          420       443       490       555       638       672       702  \
# 0  0.022885  0.042347  0.083203  0.094219  0.021251  0.025582  0.028656
# 1  0.020792  0.038067  0.074097  0.078341  0.020867  0.023750  0.028118
# 2  0.021151  0.036193  0.072673  0.063609  0.012817  0.016438  0.019991
# 3  0.026146  0.042525  0.086515  0.076021  0.013298  0.018249  0.020501
# 4  0.009466  0.022236  0.039942  0.060249  0.021883  0.035560  0.046823
#
#         742       782       865       910
# 0  0.022240  0.022023  0.008001  0.008001
# 1  0.022849  0.023057  0.007997  0.007997
# 2  0.016554  0.013742  0.004629  0.004629
# 3  0.015795  0.010634  0.003357  0.003357
# 4  0.044136  0.075338  0.031601  0.031601

# %%
fod_sampled11_copy = fod_sampled11.copy()
T0_copy = T[0].copy()

# %%
# Check the types
print("Type of fod_sampled11_copy:", type(fod_sampled11_copy))
print("Type of T0_copy:", type(T0_copy))
# Out:
# Type of fod_sampled11_copy: <class 'pandas.core.frame.DataFrame'>
# Type of T0_copy: <class 'pandas.core.series.Series'>

# %%
sand_model_gbrt = GradientBoostingRegressor(learning_rate = 0.1, max_depth = 5, n_estimators = 40, random_state = 42) 
sand_model_gbrt.fit(fod_sampled11_copy,  T0_copy)
# Out:
# GradientBoostingRegressor(max_depth=5, n_estimators=40, random_state=42)

# %%
feature_scores['Sand'] = permutation_importance(sand_model_gbrt, fod_sampled11_copy, T0_copy, n_repeats=20, random_state=0)
model_details['Sand'] = {'method': 'gbrt', 'spec': fod_sampled11, 'spec_proc': 'fod', 'n_bands': 11}

# %%
show_important_features_for ('Sand', model_details, feature_scores, 5, 40, 2)

# %% [markdown]
# ## Silt

# %% [markdown]
# ### Cubist

# %% [markdown]
# Silt -> [ r2 - **0.21**, Spec - fod, n_bands - 11]   <br/><br/>
# ***Description***:To obtain the best model for silt using cubist method we trained the model on the first order derivative of the smoothed spectra which was resampled to the 11 bands provided by Venus.

# %%
# Check the shape of the DataFrame
print("Shape of fod_sampled11:", fod_sampled11.shape)

# Check the data types of each column
print("Data types of fod_sampled11:\n", fod_sampled11.dtypes)

# Check for missing values
print("Missing values in fod_sampled11:\n", fod_sampled11.isnull().sum())

# Display the first few rows of the DataFrame
print("First few rows of fod_sampled11:\n", fod_sampled11.head())
# Out:
# Shape of fod_sampled11: (294, 11)
# Data types of fod_sampled11:
#  420    float64
# 443    float64
# 490    float64
# 555    float64
# 638    float64
# 672    float64
# 702    float64
# 742    float64
# 782    float64
# 865    float64
# 910    float64
# dtype: object
# Missing values in fod_sampled11:
#  420    0
# 443    0
# 490    0
# 555    0
# 638    0
# 672    0
# 702    0
# 742    0
# 782    0
# 865    0
# 910    0
# dtype: int64
# First few rows of fod_sampled11:
#          420       443       490       555       638       672       702  \
# 0  0.022885  0.042347  0.083203  0.094219  0.021251  0.025582  0.028656
# 1  0.020792  0.038067  0.074097  0.078341  0.020867  0.023750  0.028118
# 2  0.021151  0.036193  0.072673  0.063609  0.012817  0.016438  0.019991
# 3  0.026146  0.042525  0.086515  0.076021  0.013298  0.018249  0.020501
# 4  0.009466  0.022236  0.039942  0.060249  0.021883  0.035560  0.046823
#
#         742       782       865       910
# 0  0.022240  0.022023  0.008001  0.008001
# 1  0.022849  0.023057  0.007997  0.007997
# 2  0.016554  0.013742  0.004629  0.004629
# 3  0.015795  0.010634  0.003357  0.003357
# 4  0.044136  0.075338  0.031601  0.031601

# %%
#fod_sampled11_copy = fod_sampled11.copy()
T1_copy = T[1].copy()

# %%
# Check the types
print("Type of fod_sampled11_copy:", type(fod_sampled11_copy))
print("Type of T1_copy:", type(T1_copy))
# Out:
# Type of fod_sampled11_copy: <class 'pandas.core.frame.DataFrame'>
# Type of T1_copy: <class 'pandas.core.series.Series'>

# %%
silt_model_cubist = Cubist(n_committees = 5, n_rules = 10) 
silt_model_cubist.fit(fod_sampled11_copy,  T1_copy)
# Out:
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# Cubist(n_committees=5, n_rules=10)

# %%
feature_scores['Silt'] = permutation_importance(silt_model_cubist, fod_sampled11_copy, T1_copy, n_repeats=20, random_state=0)
model_details['Silt'] = {'method': 'cubist', 'spec': fod_sampled11, 'spec_proc': 'fod', 'n_bands': 11}
# Out:
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())
# C:\Users\abhis\AppData\Local\Programs\Python\Python311\Lib\site-packages\cubist\_make_data_string.py:67: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   x = x.applymap(lambda a: a.lstrip())

# %%
show_important_features_for ('Silt', model_details, feature_scores, 1, 40, 2)

# %% [markdown]
# ## Clay

# %% [markdown]
# ### Kernel Ridge Regression

# %% [markdown]
# Clay -> [ r2 - **0.26**, Spec - fod_log, n_bands - 11]   <br/><br/>
# ***Description***:To obtain the best model for clay using kernel ridge regression method we trained the model on the first order derivative of the logarithmic transformed spectra which was resampled to the 11 bands provided by Venus.

# %%
# Check the shape of the DataFrame
print("Shape of fod_log11:", fod_log11.shape)

# Check the data types of each column
print("Data types of fod_log11:\n", fod_log11.dtypes)

# Check for missing values
print("Missing values in fod_log11:\n", fod_log11.isnull().sum())

# Display the first few rows of the DataFrame
print("First few rows of fod_log11:\n", fod_log11.head())
# Out:
# Shape of fod_log11: (294, 11)
# Data types of fod_log11:
#  420    float64
# 443    float64
# 490    float64
# 555    float64
# 638    float64
# 672    float64
# 702    float64
# 742    float64
# 782    float64
# 865    float64
# 910    float64
# dtype: object
# Missing values in fod_log11:
#  420    0
# 443    0
# 490    0
# 555    0
# 638    0
# 672    0
# 702    0
# 742    0
# 782    0
# 865    0
# 910    0
# dtype: int64
# First few rows of fod_log11:
#          420       443       490       555       638       672       702  \
# 0 -0.145404 -0.228510 -0.334482 -0.279702 -0.053536 -0.060776 -0.064066
# 1 -0.158254 -0.242963 -0.347454 -0.270712 -0.061237 -0.065318 -0.072310
# 2 -0.190664 -0.267362 -0.381757 -0.245606 -0.042899 -0.052390 -0.060311
# 3 -0.134377 -0.190049 -0.299003 -0.205062 -0.031882 -0.042125 -0.045349
# 4 -0.149832 -0.289764 -0.370100 -0.383312 -0.109424 -0.155278 -0.174134
#
#         742       782       865       910
# 0 -0.047005 -0.044464 -0.015672 -0.015672
# 1 -0.055102 -0.052685 -0.017639 -0.017639
# 2 -0.047301 -0.037637 -0.012361 -0.012361
# 3 -0.033573 -0.021985 -0.006838 -0.006838
# 4 -0.140099 -0.201406 -0.073736 -0.073736

# %%
fod_log11_copy = fod_log11.copy()
T2_copy = T[2].copy()

# %%
# Check the types
print("Type of fod_log11_copy:", type(fod_log11_copy))
print("Type of T2_copy:", type(T2_copy))
# Out:
# Type of fod_log11_copy: <class 'pandas.core.frame.DataFrame'>
# Type of T2_copy: <class 'pandas.core.series.Series'>

# %%
clay_model_kernelridge = KernelRidge(alpha = 0.0002) 
clay_model_kernelridge.fit(fod_log11_copy,  T2_copy)
# Out:
# KernelRidge(alpha=0.0002)

# %%
feature_scores['Clay'] = permutation_importance(clay_model_kernelridge, fod_log11_copy, T2_copy, n_repeats=20, random_state=0)
model_details['Clay'] = {'method': 'ridge', 'spec': fod_log11, 'spec_proc': 'fod_log', 'n_bands': 11}

# %%
show_important_features_for ('Clay', model_details, feature_scores, 0.5, 10, 2)

# %% [markdown]
# ## TOC

# %% [markdown]
# ###  Support Vector Regression

# %% [markdown]
# TOC -> [ r2 - **0.42**, Spec - log, n_bands - 11]   <br/><br/>
# ***Description***:To obtain the best model for TOC using svr method we trained the model on the logarithmic transformed spectra which was resampled to the 11 bands provided by Venus.

# %%
# Check the shape of the DataFrame
print("Shape of sampled_log11:", sampled_log11.shape)

# Check the data types of each column
print("Data types of sampled_log11:\n", sampled_log11.dtypes)

# Check for missing values
print("Missing values in sampled_log11:\n", sampled_log11.isnull().sum())

# Display the first few rows of the DataFrame
print("First few rows of sampled_log11:\n", sampled_log11.head())
# Out:
# Shape of sampled_log11: (294, 11)
# Data types of sampled_log11:
#  420    float64
# 443    float64
# 490    float64
# 555    float64
# 638    float64
# 672    float64
# 702    float64
# 742    float64
# 782    float64
# 865    float64
# 910    float64
# dtype: object
# Missing values in sampled_log11:
#  420    0
# 443    0
# 490    0
# 555    0
# 638    0
# 672    0
# 702    0
# 742    0
# 782    0
# 865    0
# 910    0
# dtype: int64
# First few rows of sampled_log11:
#          420       443       490       555       638       672       702  \
# 0  1.938240  1.792837  1.564326  1.229844  0.950142  0.896606  0.835829
# 1  2.125960  1.967706  1.724743  1.377289  1.106576  1.045339  0.980022
# 2  2.314457  2.123793  1.856430  1.474673  1.229068  1.186168  1.133778
# 3  1.718544  1.584167  1.394117  1.095114  0.890052  0.858170  0.816045
# 4  2.857517  2.707685  2.417921  2.047820  1.664508  1.555084  1.399806
#
#         742       782       865       910
# 0  0.771763  0.724759  0.680294  0.664622
# 1  0.907712  0.852610  0.799926  0.782287
# 2  1.073468  1.026166  0.988530  0.976169
# 3  0.770696  0.737123  0.715139  0.708300
# 4  1.225673  1.085574  0.884168  0.810432

# %%
sampled_log11_copy = sampled_log11.copy()
T3_copy = T[3].copy()

# %%
# Check the types
print("Type of sampled_log11_copy:", type(sampled_log11_copy))
print("Type of T3_copy:", type(T3_copy))
# Out:
# Type of sampled_log11_copy: <class 'pandas.core.frame.DataFrame'>
# Type of T3_copy: <class 'pandas.core.series.Series'>

# %%
TOC_model_svr = SVR(C = 10, gamma = 0.01, kernel = 'linear')
TOC_model_svr.fit(sampled_log11_copy,  T3_copy)
# Out:
# SVR(C=10, gamma=0.01, kernel='linear')

# %%
feature_scores['TOC'] = permutation_importance(TOC_model_svr, sampled_log11_copy, T3_copy, n_repeats=10, random_state=0)
model_details['TOC'] = {'method': 'svr', 'spec': sampled_log11, 'spec_proc': 'log', 'n_bands': 11}

# %%
show_important_features_for ('TOC', model_details, feature_scores, 4,1.5, 2)

# %%
# with open ('Feature.pickle', 'wb') as file:
#     pickle.dump(feature_scores, file)

# %%
# with open ('Models.pickle', 'wb') as file:
#     pickle.dump(model_details, file)
