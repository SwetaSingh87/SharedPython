# %%
import pandas as pd
from IPython.display import display, HTML

# Define the data
data1 = {
    ('Target Name', ''): ["Sand", "Silt", "Clay", "TOC", "CaCO3"],
    ('Method', ''): ["SVR", "SVR", "PLSR", "SVR", "PLSR"],
    ('Model Details', 'Model Name'): ["sand_model_svr", "silt_model_svr", "clay_model_plsr", "TOC_model_svr", "CaCO3_model_plsr"],
    ('Model Details', 'Spectral Preprocessing'): ["log", "log", "log", "fod_log", "fod_log"],
    ('R2 Scores', 'Calibration'): ["0.36", "0.40", "0.56", "0.41", "0.67"],
    ('R2 Scores', 'Validation'): ["0.27", "0.12", "0.43", "0.37", "0.49"],
    ('R2 Scores', 'Leave one out'): ["0.34", "0.22", "0.49", "0.38", "0.55"],
}

# Create the DataFrame using MultiIndex for columns
df1 = pd.DataFrame(data1)

# Style the DataFrame for display in Jupyter Notebook
styled_df1 = df1.style.set_table_styles({
    ('Model Details', 'Model Name'): [{'selector': 'th', 'props': [('text-align', 'center')]}],
    ('Model Details', 'Spectral Preprocessing'): [{'selector': 'th', 'props': [('text-align', 'center')]}],
    ('R2 Scores', 'Calibration'): [{'selector': 'th', 'props': [('text-align', 'center')]}],
    ('R2 Scores', 'Validation'): [{'selector': 'th', 'props': [('text-align', 'center')]}],
    ('R2 Scores', 'Leave one out'): [{'selector': 'th', 'props': [('text-align', 'center')]}],
}).set_properties(**{'text-align': 'center'})

# Display the heading and DataFrame
display(HTML("<h2>Legacy Venus</h2>"))
display(styled_df1)
# Out:
# <h2>Legacy Venus</h2>
# <style type="text/css">
# #T_60f9a th.col2 {
#   text-align: center;
# }
# #T_60f9a th.col3 {
#   text-align: center;
# }
# #T_60f9a th.col4 {
#   text-align: center;
# }
# #T_60f9a th.col5 {
#   text-align: center;
# }
# #T_60f9a th.col6 {
#   text-align: center;
# }
# #T_60f9a_row0_col0, #T_60f9a_row0_col1, #T_60f9a_row0_col2, #T_60f9a_row0_col3, #T_60f9a_row0_col4, #T_60f9a_row0_col5, #T_60f9a_row0_col6, #T_60f9a_row1_col0, #T_60f9a_row1_col1, #T_60f9a_row1_col2, #T_60f9a_row1_col3, #T_60f9a_row1_col4, #T_60f9a_row1_col5, #T_60f9a_row1_col6, #T_60f9a_row2_col0, #T_60f9a_row2_col1, #T_60f9a_row2_col2, #T_60f9a_row2_col3, #T_60f9a_row2_col4, #T_60f9a_row2_col5, #T_60f9a_row2_col6, #T_60f9a_row3_col0, #T_60f9a_row3_col1, #T_60f9a_row3_col2, #T_60f9a_row3_col3, #T_60f9a_row3_col4, #T_60f9a_row3_col5, #T_60f9a_row3_col6, #T_60f9a_row4_col0, #T_60f9a_row4_col1, #T_60f9a_row4_col2, #T_60f9a_row4_col3, #T_60f9a_row4_col4, #T_60f9a_row4_col5, #T_60f9a_row4_col6 {
#   text-align: center;
# }
# </style>
# <table id="T_60f9a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_60f9a_level0_col0" class="col_heading level0 col0" >Target Name</th>
#       <th id="T_60f9a_level0_col1" class="col_heading level0 col1" >Method</th>
#       <th id="T_60f9a_level0_col2" class="col_heading level0 col2" colspan="2">Model Details</th>
#       <th id="T_60f9a_level0_col4" class="col_heading level0 col4" colspan="3">R2 Scores</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_60f9a_level1_col0" class="col_heading level1 col0" ></th>
#       <th id="T_60f9a_level1_col1" class="col_heading level1 col1" ></th>
#       <th id="T_60f9a_level1_col2" class="col_heading level1 col2" >Model Name</th>
#       <th id="T_60f9a_level1_col3" class="col_heading level1 col3" >Spectral Preprocessing</th>
#       <th id="T_60f9a_level1_col4" class="col_heading level1 col4" >Calibration</th>
#       <th id="T_60f9a_level1_col5" class="col_heading level1 col5" >Validation</th>
#       <th id="T_60f9a_level1_col6" class="col_heading level1 col6" >Leave one out</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_60f9a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_60f9a_row0_col0" class="data row0 col0" >Sand</td>
#       <td id="T_60f9a_row0_col1" class="data row0 col1" >SVR</td>
#       <td id="T_60f9a_row0_col2" class="data row0 col2" >sand_model_svr</td>
#       <td id="T_60f9a_row0_col3" class="data row0 col3" >log</td>
#       <td id="T_60f9a_row0_col4" class="data row0 col4" >0.36</td>
#       <td id="T_60f9a_row0_col5" class="data row0 col5" >0.27</td>
#       <td id="T_60f9a_row0_col6" class="data row0 col6" >0.34</td>
#     </tr>
#     <tr>
#       <th id="T_60f9a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_60f9a_row1_col0" class="data row1 col0" >Silt</td>
#       <td id="T_60f9a_row1_col1" class="data row1 col1" >SVR</td>
#       <td id="T_60f9a_row1_col2" class="data row1 col2" >silt_model_svr</td>
#       <td id="T_60f9a_row1_col3" class="data row1 col3" >log</td>
#       <td id="T_60f9a_row1_col4" class="data row1 col4" >0.40</td>
#       <td id="T_60f9a_row1_col5" class="data row1 col5" >0.12</td>
#       <td id="T_60f9a_row1_col6" class="data row1 col6" >0.22</td>
#     </tr>
#     <tr>
#       <th id="T_60f9a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_60f9a_row2_col0" class="data row2 col0" >Clay</td>
#       <td id="T_60f9a_row2_col1" class="data row2 col1" >PLSR</td>
#       <td id="T_60f9a_row2_col2" class="data row2 col2" >clay_model_plsr</td>
#       <td id="T_60f9a_row2_col3" class="data row2 col3" >log</td>
#       <td id="T_60f9a_row2_col4" class="data row2 col4" >0.56</td>
#       <td id="T_60f9a_row2_col5" class="data row2 col5" >0.43</td>
#       <td id="T_60f9a_row2_col6" class="data row2 col6" >0.49</td>
#     </tr>
#     <tr>
#       <th id="T_60f9a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_60f9a_row3_col0" class="data row3 col0" >TOC</td>
#       <td id="T_60f9a_row3_col1" class="data row3 col1" >SVR</td>
#       <td id="T_60f9a_row3_col2" class="data row3 col2" >TOC_model_svr</td>
#       <td id="T_60f9a_row3_col3" class="data row3 col3" >fod_log</td>
#       <td id="T_60f9a_row3_col4" class="data row3 col4" >0.41</td>
#       <td id="T_60f9a_row3_col5" class="data row3 col5" >0.37</td>
#       <td id="T_60f9a_row3_col6" class="data row3 col6" >0.38</td>
#     </tr>
#     <tr>
#       <th id="T_60f9a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_60f9a_row4_col0" class="data row4 col0" >CaCO3</td>
#       <td id="T_60f9a_row4_col1" class="data row4 col1" >PLSR</td>
#       <td id="T_60f9a_row4_col2" class="data row4 col2" >CaCO3_model_plsr</td>
#       <td id="T_60f9a_row4_col3" class="data row4 col3" >fod_log</td>
#       <td id="T_60f9a_row4_col4" class="data row4 col4" >0.67</td>
#       <td id="T_60f9a_row4_col5" class="data row4 col5" >0.49</td>
#       <td id="T_60f9a_row4_col6" class="data row4 col6" >0.55</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Convert DataFrames to HTML with headings
html_content = f"""
<html>
<head><title>Data Export</title></head>
<body>
    <h2 style='text-align: center;'>Legacy Venus</h2>
    {styled_df1.to_html(index=False)}
</body>
</html>
"""

# Write to an HTML file
with open('Legacy_Venus.html', 'w') as f:
    f.write(html_content)

print("HTML file with headings generated successfully.")
# Out:
# HTML file with headings generated successfully.

# %%
# Define the data
data2 = {
    ('Target Name', ''): ["Sand", "Silt", "Clay", "TOC", "CaCO3"],
    ('Method', ''): ["PLSR", "PLSR", "PLSR", "SVR", "PLSR"],
    ('Model Details', 'Model Name'): ["sand_model_plsr", "silt_model_plsr", "clay_model_plsr", "TOC_model_svr", "CaCO3_model_plsr"],
    ('Model Details', 'Spectral Preprocessing'): ["fod", "fod", "log", "fod_log", "fod"],
    ('R2 Scores', 'Calibration'): ["0.60", "0.44", "0.61", "0.45", "0.73"],
    ('R2 Scores', 'Validation'): ["0.48", "0.25", "0.54", "0.39", "0.55"],
    ('R2 Scores', 'Leave one out'): ["0.54", "0.34", "0.60", "0.40", "0.61"],
}

# Create the DataFrame using MultiIndex for columns
df2 = pd.DataFrame(data2)

# Style the DataFrame for display in Jupyter Notebook
styled_df2 = df2.style.set_table_styles({
    ('Model Details', 'Model Name'): [{'selector': 'th', 'props': [('text-align', 'center')]}],
    ('Model Details', 'Spectral Preprocessing'): [{'selector': 'th', 'props': [('text-align', 'center')]}],
    ('R2 Scores', 'Calibration'): [{'selector': 'th', 'props': [('text-align', 'center')]}],
    ('R2 Scores', 'Validation'): [{'selector': 'th', 'props': [('text-align', 'center')]}],
    ('R2 Scores', 'Leave one out'): [{'selector': 'th', 'props': [('text-align', 'center')]}],
}).set_properties(**{'text-align': 'center'})

# Display the heading and DataFrame
display(HTML("<h2>Legacy Sentinel</h2>"))
display(styled_df2)
# Out:
# <h2>Legacy Sentinel</h2>
# <style type="text/css">
# #T_474b1 th.col2 {
#   text-align: center;
# }
# #T_474b1 th.col3 {
#   text-align: center;
# }
# #T_474b1 th.col4 {
#   text-align: center;
# }
# #T_474b1 th.col5 {
#   text-align: center;
# }
# #T_474b1 th.col6 {
#   text-align: center;
# }
# #T_474b1_row0_col0, #T_474b1_row0_col1, #T_474b1_row0_col2, #T_474b1_row0_col3, #T_474b1_row0_col4, #T_474b1_row0_col5, #T_474b1_row0_col6, #T_474b1_row1_col0, #T_474b1_row1_col1, #T_474b1_row1_col2, #T_474b1_row1_col3, #T_474b1_row1_col4, #T_474b1_row1_col5, #T_474b1_row1_col6, #T_474b1_row2_col0, #T_474b1_row2_col1, #T_474b1_row2_col2, #T_474b1_row2_col3, #T_474b1_row2_col4, #T_474b1_row2_col5, #T_474b1_row2_col6, #T_474b1_row3_col0, #T_474b1_row3_col1, #T_474b1_row3_col2, #T_474b1_row3_col3, #T_474b1_row3_col4, #T_474b1_row3_col5, #T_474b1_row3_col6, #T_474b1_row4_col0, #T_474b1_row4_col1, #T_474b1_row4_col2, #T_474b1_row4_col3, #T_474b1_row4_col4, #T_474b1_row4_col5, #T_474b1_row4_col6 {
#   text-align: center;
# }
# </style>
# <table id="T_474b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_474b1_level0_col0" class="col_heading level0 col0" >Target Name</th>
#       <th id="T_474b1_level0_col1" class="col_heading level0 col1" >Method</th>
#       <th id="T_474b1_level0_col2" class="col_heading level0 col2" colspan="2">Model Details</th>
#       <th id="T_474b1_level0_col4" class="col_heading level0 col4" colspan="3">R2 Scores</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_474b1_level1_col0" class="col_heading level1 col0" ></th>
#       <th id="T_474b1_level1_col1" class="col_heading level1 col1" ></th>
#       <th id="T_474b1_level1_col2" class="col_heading level1 col2" >Model Name</th>
#       <th id="T_474b1_level1_col3" class="col_heading level1 col3" >Spectral Preprocessing</th>
#       <th id="T_474b1_level1_col4" class="col_heading level1 col4" >Calibration</th>
#       <th id="T_474b1_level1_col5" class="col_heading level1 col5" >Validation</th>
#       <th id="T_474b1_level1_col6" class="col_heading level1 col6" >Leave one out</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_474b1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_474b1_row0_col0" class="data row0 col0" >Sand</td>
#       <td id="T_474b1_row0_col1" class="data row0 col1" >PLSR</td>
#       <td id="T_474b1_row0_col2" class="data row0 col2" >sand_model_plsr</td>
#       <td id="T_474b1_row0_col3" class="data row0 col3" >fod</td>
#       <td id="T_474b1_row0_col4" class="data row0 col4" >0.60</td>
#       <td id="T_474b1_row0_col5" class="data row0 col5" >0.48</td>
#       <td id="T_474b1_row0_col6" class="data row0 col6" >0.54</td>
#     </tr>
#     <tr>
#       <th id="T_474b1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_474b1_row1_col0" class="data row1 col0" >Silt</td>
#       <td id="T_474b1_row1_col1" class="data row1 col1" >PLSR</td>
#       <td id="T_474b1_row1_col2" class="data row1 col2" >silt_model_plsr</td>
#       <td id="T_474b1_row1_col3" class="data row1 col3" >fod</td>
#       <td id="T_474b1_row1_col4" class="data row1 col4" >0.44</td>
#       <td id="T_474b1_row1_col5" class="data row1 col5" >0.25</td>
#       <td id="T_474b1_row1_col6" class="data row1 col6" >0.34</td>
#     </tr>
#     <tr>
#       <th id="T_474b1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_474b1_row2_col0" class="data row2 col0" >Clay</td>
#       <td id="T_474b1_row2_col1" class="data row2 col1" >PLSR</td>
#       <td id="T_474b1_row2_col2" class="data row2 col2" >clay_model_plsr</td>
#       <td id="T_474b1_row2_col3" class="data row2 col3" >log</td>
#       <td id="T_474b1_row2_col4" class="data row2 col4" >0.61</td>
#       <td id="T_474b1_row2_col5" class="data row2 col5" >0.54</td>
#       <td id="T_474b1_row2_col6" class="data row2 col6" >0.60</td>
#     </tr>
#     <tr>
#       <th id="T_474b1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_474b1_row3_col0" class="data row3 col0" >TOC</td>
#       <td id="T_474b1_row3_col1" class="data row3 col1" >SVR</td>
#       <td id="T_474b1_row3_col2" class="data row3 col2" >TOC_model_svr</td>
#       <td id="T_474b1_row3_col3" class="data row3 col3" >fod_log</td>
#       <td id="T_474b1_row3_col4" class="data row3 col4" >0.45</td>
#       <td id="T_474b1_row3_col5" class="data row3 col5" >0.39</td>
#       <td id="T_474b1_row3_col6" class="data row3 col6" >0.40</td>
#     </tr>
#     <tr>
#       <th id="T_474b1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_474b1_row4_col0" class="data row4 col0" >CaCO3</td>
#       <td id="T_474b1_row4_col1" class="data row4 col1" >PLSR</td>
#       <td id="T_474b1_row4_col2" class="data row4 col2" >CaCO3_model_plsr</td>
#       <td id="T_474b1_row4_col3" class="data row4 col3" >fod</td>
#       <td id="T_474b1_row4_col4" class="data row4 col4" >0.73</td>
#       <td id="T_474b1_row4_col5" class="data row4 col5" >0.55</td>
#       <td id="T_474b1_row4_col6" class="data row4 col6" >0.61</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Convert DataFrames to HTML with headings
html_content = f"""
<html>
<head><title>Data Export</title></head>
<body>
    <h2 style='text-align: center;'>Legacy Sentinel</h2>
    {styled_df2.to_html(index=False)}
</body>
</html>
"""

# Write to an HTML file
with open('Legacy_Sentinel.html', 'w') as f:
    f.write(html_content)

print("HTML file with headings generated successfully.")
# Out:
# HTML file with headings generated successfully.
