# %% [markdown]
# # Importing Header, SoilPrep, and PlotFunctions

# %%
import import_ipynb 
from Header import *

import import_ipynb
from SoilPrep import *
# Out:
# importing Jupyter notebook from Header.ipynb
# importing Jupyter notebook from SoilPrep.ipynb

# %%
import import_ipynb
from PlotFunctions import *
# Out:
# importing Jupyter notebook from PlotFunctions.ipynb
# importing Jupyter notebook from LoadDataMetaData.ipynb
# C:\Users\abhis\anaconda3\lib\site-packages\nbformat\__init__.py:92: MissingIDFieldWarning: Code cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   validate(nb)

# %%
import import_ipynb
from HyperMainSentinelNew import *
# Out:
# importing Jupyter notebook from HyperMainSentinelNew.ipynb
# tree for: mult ------> running on: Sand
# Fitting 86 folds for each of 2 candidates, totalling 172 fits
# Method: mult---> Target: Sand----> SpecProc: none ---> n_band: 10
# Fitting 86 folds for each of 2 candidates, totalling 172 fits
# Method: mult---> Target: Sand----> SpecProc: fod2 ---> n_band: 10
# Fitting 86 folds for each of 2 candidates, totalling 172 fits
# Method: mult---> Target: Sand----> SpecProc: cr ---> n_band: 10
# Fitting 86 folds for each of 2 candidates, totalling 172 fits
# Method: mult---> Target: Sand----> SpecProc: log ---> n_band: 10
# End time - Start time = 10.332248449325562
# tree for: mult ------> running on: Silt
# Fitting 86 folds for each of 2 candidates, totalling 172 fits
# Method: mult---> Target: Silt----> SpecProc: none ---> n_band: 10
# Fitting 86 folds for each of 2 candidates, totalling 172 fits
# Method: mult---> Target: Silt----> SpecProc: fod2 ---> n_band: 10
# Fitting 86 folds for each of 2 candidates, totalling 172 fits
# Method: mult---> Target: Silt----> SpecProc: cr ---> n_band: 10
# Fitting 86 folds for each of 2 candidates, totalling 172 fits
# Method: mult---> Target: Silt----> SpecProc: log ---> n_band: 10
# End time - Start time = 6.772649765014648
# tree for: mult ------> running on: Clay
# Fitting 86 folds for each of 2 candidates, totalling 172 fits
# Method: mult---> Target: Clay----> SpecProc: none ---> n_band: 10
# Fitting 86 folds for each of 2 candidates, totalling 172 fits
# Method: mult---> Target: Clay----> SpecProc: fod2 ---> n_band: 10
# Fitting 86 folds for each of 2 candidates, totalling 172 fits
# Method: mult---> Target: Clay----> SpecProc: cr ---> n_band: 10
# Fitting 86 folds for each of 2 candidates, totalling 172 fits
# Method: mult---> Target: Clay----> SpecProc: log ---> n_band: 10
# End time - Start time = 5.6867828369140625
# tree for: mult ------> running on: TOC
# Fitting 86 folds for each of 2 candidates, totalling 172 fits
# Method: mult---> Target: TOC----> SpecProc: none ---> n_band: 10
# Fitting 86 folds for each of 2 candidates, totalling 172 fits
# Method: mult---> Target: TOC----> SpecProc: fod2 ---> n_band: 10
# Fitting 86 folds for each of 2 candidates, totalling 172 fits
# Method: mult---> Target: TOC----> SpecProc: cr ---> n_band: 10
# Fitting 86 folds for each of 2 candidates, totalling 172 fits
# Method: mult---> Target: TOC----> SpecProc: log ---> n_band: 10
# End time - Start time = 5.455397844314575
# tree for: mult ------> running on: CaCO3
# Fitting 86 folds for each of 2 candidates, totalling 172 fits
# Method: mult---> Target: CaCO3----> SpecProc: none ---> n_band: 10
# Fitting 86 folds for each of 2 candidates, totalling 172 fits
# Method: mult---> Target: CaCO3----> SpecProc: fod2 ---> n_band: 10
# Fitting 86 folds for each of 2 candidates, totalling 172 fits
# Method: mult---> Target: CaCO3----> SpecProc: cr ---> n_band: 10
# Fitting 86 folds for each of 2 candidates, totalling 172 fits
# Method: mult---> Target: CaCO3----> SpecProc: log ---> n_band: 10
# End time - Start time = 6.188143491744995
# End time - Start time = 34.62576389312744
# tree for: plsr ------> running on: Sand
# Fitting 86 folds for each of 10 candidates, totalling 860 fits
# Method: plsr---> Target: Sand----> SpecProc: none ---> n_band: 10
# Fitting 86 folds for each of 10 candidates, totalling 860 fits
# Method: plsr---> Target: Sand----> SpecProc: fod2 ---> n_band: 10
# Fitting 86 folds for each of 10 candidates, totalling 860 fits
# Method: plsr---> Target: Sand----> SpecProc: cr ---> n_band: 10
# Fitting 86 folds for each of 10 candidates, totalling 860 fits
# Method: plsr---> Target: Sand----> SpecProc: log ---> n_band: 10
# End time - Start time = 18.058560132980347
# tree for: plsr ------> running on: Silt
# Fitting 86 folds for each of 10 candidates, totalling 860 fits
# Method: plsr---> Target: Silt----> SpecProc: none ---> n_band: 10
# Fitting 86 folds for each of 10 candidates, totalling 860 fits
# Method: plsr---> Target: Silt----> SpecProc: fod2 ---> n_band: 10
# Fitting 86 folds for each of 10 candidates, totalling 860 fits
# Method: plsr---> Target: Silt----> SpecProc: cr ---> n_band: 10
# Fitting 86 folds for each of 10 candidates, totalling 860 fits
# Method: plsr---> Target: Silt----> SpecProc: log ---> n_band: 10
# End time - Start time = 19.777649879455566
# tree for: plsr ------> running on: Clay
# Fitting 86 folds for each of 10 candidates, totalling 860 fits
# Method: plsr---> Target: Clay----> SpecProc: none ---> n_band: 10
# Fitting 86 folds for each of 10 candidates, totalling 860 fits
# Method: plsr---> Target: Clay----> SpecProc: fod2 ---> n_band: 10
# Fitting 86 folds for each of 10 candidates, totalling 860 fits
# Method: plsr---> Target: Clay----> SpecProc: cr ---> n_band: 10
# Fitting 86 folds for each of 10 candidates, totalling 860 fits
# Method: plsr---> Target: Clay----> SpecProc: log ---> n_band: 10
# End time - Start time = 18.54004716873169
# tree for: plsr ------> running on: TOC
# Fitting 86 folds for each of 10 candidates, totalling 860 fits
# Method: plsr---> Target: TOC----> SpecProc: none ---> n_band: 10
# Fitting 86 folds for each of 10 candidates, totalling 860 fits
# Method: plsr---> Target: TOC----> SpecProc: fod2 ---> n_band: 10
# Fitting 86 folds for each of 10 candidates, totalling 860 fits
# Method: plsr---> Target: TOC----> SpecProc: cr ---> n_band: 10
# Fitting 86 folds for each of 10 candidates, totalling 860 fits
# Method: plsr---> Target: TOC----> SpecProc: log ---> n_band: 10
# End time - Start time = 18.839510202407837
# tree for: plsr ------> running on: CaCO3
# Fitting 86 folds for each of 10 candidates, totalling 860 fits
# Method: plsr---> Target: CaCO3----> SpecProc: none ---> n_band: 10
# Fitting 86 folds for each of 10 candidates, totalling 860 fits
# Method: plsr---> Target: CaCO3----> SpecProc: fod2 ---> n_band: 10
# Fitting 86 folds for each of 10 candidates, totalling 860 fits
# Method: plsr---> Target: CaCO3----> SpecProc: cr ---> n_band: 10
# Fitting 86 folds for each of 10 candidates, totalling 860 fits
# Method: plsr---> Target: CaCO3----> SpecProc: log ---> n_band: 10
# End time - Start time = 18.31374454498291
# End time - Start time = 93.71133542060852
# tree for: svr ------> running on: Sand
# Fitting 86 folds for each of 18 candidates, totalling 1548 fits
# Method: svr---> Target: Sand----> SpecProc: none ---> n_band: 10
# Fitting 86 folds for each of 18 candidates, totalling 1548 fits
# Method: svr---> Target: Sand----> SpecProc: fod2 ---> n_band: 10
# Fitting 86 folds for each of 18 candidates, totalling 1548 fits
# Method: svr---> Target: Sand----> SpecProc: cr ---> n_band: 10
# Fitting 86 folds for each of 18 candidates, totalling 1548 fits
# Method: svr---> Target: Sand----> SpecProc: log ---> n_band: 10
# End time - Start time = 25.091368436813354
# tree for: svr ------> running on: Silt
# Fitting 86 folds for each of 18 candidates, totalling 1548 fits
# Method: svr---> Target: Silt----> SpecProc: none ---> n_band: 10
# Fitting 86 folds for each of 18 candidates, totalling 1548 fits
# Method: svr---> Target: Silt----> SpecProc: fod2 ---> n_band: 10
# Fitting 86 folds for each of 18 candidates, totalling 1548 fits
# Method: svr---> Target: Silt----> SpecProc: cr ---> n_band: 10
# Fitting 86 folds for each of 18 candidates, totalling 1548 fits
# Method: svr---> Target: Silt----> SpecProc: log ---> n_band: 10
# End time - Start time = 24.491955041885376
# tree for: svr ------> running on: Clay
# Fitting 86 folds for each of 18 candidates, totalling 1548 fits
# Method: svr---> Target: Clay----> SpecProc: none ---> n_band: 10
# Fitting 86 folds for each of 18 candidates, totalling 1548 fits
# Method: svr---> Target: Clay----> SpecProc: fod2 ---> n_band: 10
# Fitting 86 folds for each of 18 candidates, totalling 1548 fits
# Method: svr---> Target: Clay----> SpecProc: cr ---> n_band: 10
# Fitting 86 folds for each of 18 candidates, totalling 1548 fits
# Method: svr---> Target: Clay----> SpecProc: log ---> n_band: 10
# End time - Start time = 25.487736225128174
# tree for: svr ------> running on: TOC
# Fitting 86 folds for each of 18 candidates, totalling 1548 fits
# Method: svr---> Target: TOC----> SpecProc: none ---> n_band: 10
# Fitting 86 folds for each of 18 candidates, totalling 1548 fits
# Method: svr---> Target: TOC----> SpecProc: fod2 ---> n_band: 10
# Fitting 86 folds for each of 18 candidates, totalling 1548 fits
# Method: svr---> Target: TOC----> SpecProc: cr ---> n_band: 10
# Fitting 86 folds for each of 18 candidates, totalling 1548 fits
# Method: svr---> Target: TOC----> SpecProc: log ---> n_band: 10
# End time - Start time = 25.986401319503784
# tree for: svr ------> running on: CaCO3
# Fitting 86 folds for each of 18 candidates, totalling 1548 fits
# Method: svr---> Target: CaCO3----> SpecProc: none ---> n_band: 10
# Fitting 86 folds for each of 18 candidates, totalling 1548 fits
# Method: svr---> Target: CaCO3----> SpecProc: fod2 ---> n_band: 10
# Fitting 86 folds for each of 18 candidates, totalling 1548 fits
# Method: svr---> Target: CaCO3----> SpecProc: cr ---> n_band: 10
# Fitting 86 folds for each of 18 candidates, totalling 1548 fits
# Method: svr---> Target: CaCO3----> SpecProc: log ---> n_band: 10
# End time - Start time = 24.77645468711853
# End time - Start time = 126.01825046539307
# tree for: ridge ------> running on: Sand
# Fitting 86 folds for each of 14 candidates, totalling 1204 fits
# Method: ridge---> Target: Sand----> SpecProc: none ---> n_band: 10
# Fitting 86 folds for each of 14 candidates, totalling 1204 fits
# Method: ridge---> Target: Sand----> SpecProc: fod2 ---> n_band: 10
# Fitting 86 folds for each of 14 candidates, totalling 1204 fits
# Method: ridge---> Target: Sand----> SpecProc: cr ---> n_band: 10
# Fitting 86 folds for each of 14 candidates, totalling 1204 fits
# Method: ridge---> Target: Sand----> SpecProc: log ---> n_band: 10
# End time - Start time = 19.157219886779785
# tree for: ridge ------> running on: Silt
# Fitting 86 folds for each of 14 candidates, totalling 1204 fits
# Method: ridge---> Target: Silt----> SpecProc: none ---> n_band: 10
# Fitting 86 folds for each of 14 candidates, totalling 1204 fits
# Method: ridge---> Target: Silt----> SpecProc: fod2 ---> n_band: 10
# Fitting 86 folds for each of 14 candidates, totalling 1204 fits
# Method: ridge---> Target: Silt----> SpecProc: cr ---> n_band: 10
# Fitting 86 folds for each of 14 candidates, totalling 1204 fits
# Method: ridge---> Target: Silt----> SpecProc: log ---> n_band: 10
# End time - Start time = 18.94460105895996
# tree for: ridge ------> running on: Clay
# Fitting 86 folds for each of 14 candidates, totalling 1204 fits
# Method: ridge---> Target: Clay----> SpecProc: none ---> n_band: 10
# Fitting 86 folds for each of 14 candidates, totalling 1204 fits
# Method: ridge---> Target: Clay----> SpecProc: fod2 ---> n_band: 10
# Fitting 86 folds for each of 14 candidates, totalling 1204 fits
# Method: ridge---> Target: Clay----> SpecProc: cr ---> n_band: 10
# Fitting 86 folds for each of 14 candidates, totalling 1204 fits
# Method: ridge---> Target: Clay----> SpecProc: log ---> n_band: 10
# End time - Start time = 19.187615633010864
# tree for: ridge ------> running on: TOC
# Fitting 86 folds for each of 14 candidates, totalling 1204 fits
# Method: ridge---> Target: TOC----> SpecProc: none ---> n_band: 10
# Fitting 86 folds for each of 14 candidates, totalling 1204 fits
# Method: ridge---> Target: TOC----> SpecProc: fod2 ---> n_band: 10
# Fitting 86 folds for each of 14 candidates, totalling 1204 fits
# Method: ridge---> Target: TOC----> SpecProc: cr ---> n_band: 10
# Fitting 86 folds for each of 14 candidates, totalling 1204 fits
# Method: ridge---> Target: TOC----> SpecProc: log ---> n_band: 10
# End time - Start time = 19.259190797805786
# tree for: ridge ------> running on: CaCO3
# Fitting 86 folds for each of 14 candidates, totalling 1204 fits
# Method: ridge---> Target: CaCO3----> SpecProc: none ---> n_band: 10
# Fitting 86 folds for each of 14 candidates, totalling 1204 fits
# Method: ridge---> Target: CaCO3----> SpecProc: fod2 ---> n_band: 10
# Fitting 86 folds for each of 14 candidates, totalling 1204 fits
# Method: ridge---> Target: CaCO3----> SpecProc: cr ---> n_band: 10
# Fitting 86 folds for each of 14 candidates, totalling 1204 fits
# Method: ridge---> Target: CaCO3----> SpecProc: log ---> n_band: 10
# End time - Start time = 18.926061630249023
# End time - Start time = 95.66180348396301
# tree for: cubist ------> running on: Sand
# Fitting 86 folds for each of 20 candidates, totalling 1720 fits
# Method: cubist---> Target: Sand----> SpecProc: none ---> n_band: 10
# Fitting 86 folds for each of 20 candidates, totalling 1720 fits
# Method: cubist---> Target: Sand----> SpecProc: fod2 ---> n_band: 10
# Fitting 86 folds for each of 20 candidates, totalling 1720 fits
# Method: cubist---> Target: Sand----> SpecProc: cr ---> n_band: 10
# Fitting 86 folds for each of 20 candidates, totalling 1720 fits

# %% [markdown]
# ## Loading  Mtree

# %%
with open ('HMtreeSenNew.pickle', 'rb') as file:
    HMtreeSenNew = pickle.load(file)

# %% [markdown]
#  #  Best Models for Sand, Silt, Clay, TOC, and CaCO3..

# %%
feature_scores = {}

model_details ={}

# %%
HMtreeSenNew['plsr']['Silt']['none']['fod2']
# Out:
# {'bp': {'n_components': 4},
#  'X_test':          493       560       665       704       741       783       833  \
#  76  0.092232  0.103406  0.028157  0.023571  0.019460  0.012313  0.006098
#  0   0.049058  0.096656  0.028886  0.025786  0.020817  0.013582  0.007529
#  71  0.086641  0.100433  0.028638  0.024143  0.020397  0.013197  0.006692
#  23  0.029648  0.050024  0.016800  0.015429  0.014238  0.012487  0.007146
#  12  0.067791  0.094045  0.026367  0.023286  0.020159  0.015354  0.008502
#  57  0.150195  0.130608  0.035249  0.026286  0.016875  0.004678  0.000769
#  10  0.139684  0.132174  0.034654  0.028637  0.023852  0.013907  0.006707
#  19  0.047998  0.065271  0.026044  0.022986  0.022804  0.022374  0.013425
#  4   0.051135  0.071463  0.015638  0.013071  0.006246 -0.002937 -0.002652
#  68  0.147134  0.137698  0.031841  0.024224  0.014960  0.002803 -0.000143
#  62  0.033641  0.051815  0.022151  0.021350  0.023705  0.026805  0.016804
#  65  0.036477  0.045267  0.018225  0.016797  0.017811  0.018188  0.010950
#  54  0.093176  0.114595  0.030791  0.025939  0.022793  0.019663  0.011363
#  74  0.089411  0.112190  0.030205  0.025357  0.020294  0.012085  0.005842
#  63  0.032808  0.052435  0.022753  0.022224  0.025367  0.029826  0.018964
#  67  0.121970  0.087031  0.028305  0.026214  0.011937 -0.008443 -0.007529
#  34  0.034741  0.067205  0.016439  0.013927  0.011003  0.006726  0.003569
#  79  0.095474  0.109878  0.031281  0.026142  0.021430  0.013838  0.007042
#  55  0.108625  0.107114  0.038798  0.034627  0.026810  0.014692  0.006830
#  73  0.094108  0.113235  0.030000  0.024714  0.019563  0.010790  0.005083
#  11  0.080415  0.094832  0.033011  0.026123  0.024515  0.020975  0.011686
#  31  0.030204  0.066459  0.018727  0.016107  0.011737  0.006667  0.003638
#  41  0.048330  0.082643  0.016605  0.012000  0.006651 -0.000328 -0.001244
#  29  0.034552  0.062198  0.016308  0.014224  0.011992  0.007951  0.004192
#  9   0.045763  0.068669  0.025067  0.023286  0.022937  0.021259  0.012619
#  66  0.132233  0.154637  0.032784  0.025102  0.015319  0.002261 -0.000382
#
#           865      1614      2202
#  76  0.114333 -0.025754 -0.025754
#  0   0.138300 -0.008829 -0.008829
#  71  0.114622 -0.021662 -0.021662
#  23  0.057378 -0.026632 -0.026632
#  12  0.093033 -0.007690 -0.007690
#  57  0.082905 -0.063328 -0.063328
#  10  0.190898 -0.025712 -0.025712
#  19  0.125722 -0.043168 -0.043168
#  4   0.008144 -0.008703 -0.008703
#  68  0.080610 -0.044447 -0.044447
#  62  0.213467 -0.000682 -0.000682
#  65  0.097412 -0.033544 -0.033544
#  54  0.123836 -0.033381 -0.033381
#  74  0.116906 -0.032935 -0.032935
#  63  0.265052  0.010577  0.010577
#  67  0.076717 -0.157731 -0.157731
#  34  0.032171 -0.013475 -0.013475
#  79  0.116243 -0.023604 -0.023604
#  55  0.125490 -0.107168 -0.107168
#  73  0.105917 -0.031141 -0.031141
#  11  0.115826 -0.095666 -0.095666
#  31  0.064161 -0.021936 -0.021936
#  41 -0.012150 -0.024443 -0.024443
#  29  0.021931 -0.018614 -0.018614
#  9   0.160100 -0.001769 -0.001769
#  66  0.046001 -0.075084 -0.075084  ,
#  'y_test': 76     8.9723
#  0      0.0000
#  71    14.2341
#  23    24.4512
#  12    22.9545
#  57    33.6265
#  10     0.0000
#  19    18.2735
#  4      5.2072
#  68    13.9464
#  62    25.2226
#  65    31.5720
#  54    30.9949
#  74    12.9789
#  63    21.1082
#  67    33.8895
#  34    18.7831
#  79    11.4461
#  55    59.6906
#  73    12.8932
#  11    44.8908
#  31    40.3139
#  41    27.0416
#  29    16.6168
#  9      2.5176
#  66    29.8678
#  Name: Silt, dtype: float64,
#  'y_testP': array([[20.45262069],
#         [10.31133351],
#         [19.8633782 ],
#         [21.80732819],
#         [20.33877977],
#         [27.04793121],
#         [18.82677827],
#         [27.43869964],
#         [11.24047559],
#         [23.18125243],
#         [16.13928864],
#         [25.57770634],
#         [27.88458316],
#         [19.75258799],
#         [12.12301194],
#         [24.5987756 ],
#         [17.39343963],
#         [20.94103397],
#         [31.60389096],
#         [20.17579495],
#         [37.12518897],
#         [13.70154541],
#         [17.99854143],
#         [20.4559635 ],
#         [16.31170454],
#         [28.28541679]]),
#  'X_train':          493       560       665       704       741       783       833  \
#  5   0.046460  0.156603  0.039449  0.031661  0.012187 -0.005600 -0.004053
#  40  0.054197  0.086247  0.017829  0.013643  0.008540  0.001687  0.000202
#  32  0.024743  0.051282  0.018124  0.016985  0.015640  0.013236  0.007738
#  36  0.034964  0.042586  0.013288  0.011925  0.011624  0.009579  0.005303
#  46  0.092337  0.135907  0.032627  0.025915  0.020892  0.014499  0.007824
#  45  0.093726  0.123704  0.033276  0.026844  0.021885  0.015165  0.008039
#  17  0.046142  0.055871  0.025041  0.021587  0.020156  0.018315  0.010600
#  43  0.075302  0.131206  0.028429  0.022071  0.017278  0.011665  0.006458
#  35  0.042804  0.053430  0.017120  0.015492  0.015093  0.012836  0.007279
#  7   0.086823  0.225231  0.046462  0.036000  0.016071 -0.001750 -0.001650
#  50  0.064063  0.091500  0.026357  0.022500  0.019476  0.014859  0.008208
#  83  0.113055  0.117952  0.028188  0.021848  0.015664  0.005365  0.001435
#  20  0.090528  0.113165  0.031276  0.026619  0.022857  0.017155  0.009498
#  84  0.110522  0.131313  0.034642  0.027945  0.020859  0.010340  0.004493
#  26  0.041275  0.071224  0.022743  0.020857  0.019667  0.018256  0.010877
#  48  0.022819  0.036960  0.010681  0.009218  0.007182  0.003012  0.001000
#  13  0.033266  0.047655  0.015648  0.014643  0.014198  0.012569  0.007275
#  25  0.041256  0.072933  0.021781  0.019714  0.018071  0.016260  0.009690
#  3   0.042079  0.088727  0.026924  0.024143  0.019389  0.012284  0.006627
#  18  0.055661  0.076074  0.026678  0.023148  0.020599  0.015751  0.008605
#  39  0.036174  0.047129  0.015400  0.014357  0.014421  0.013895  0.008327
#  8   0.128079  0.158365  0.034114  0.027857  0.021373  0.011075  0.005281
#  69  0.063371  0.077218  0.021040  0.017406  0.014286  0.008847  0.004416
#  6   0.048663  0.171193  0.045076  0.036571  0.015952 -0.003782 -0.002885
#  56  0.098345  0.086726  0.026837  0.020888  0.015297  0.007524  0.002969
#  37  0.017866  0.019453  0.007186  0.007143  0.006905  0.005426  0.002890
#  78  0.102184  0.118901  0.031937  0.025361  0.020102  0.011774  0.005608
#  86  0.130544  0.137226  0.034416  0.027646  0.019056  0.007035  0.002426
#  44  0.089285  0.128790  0.029369  0.022237  0.016586  0.009140  0.004390
#  51  0.020864  0.032539  0.010026  0.009768  0.009951  0.009960  0.006103
#  47  0.075180  0.113182  0.030200  0.024571  0.020817  0.015986  0.008725
#  85  0.110561  0.123577  0.030151  0.023304  0.016031  0.004574  0.000848
#  15  0.042487  0.063398  0.029276  0.026615  0.026966  0.026271  0.015445
#  70  0.065808  0.078110  0.023638  0.020429  0.017889  0.012650  0.006762
#  28  0.073376  0.096446  0.029461  0.026143  0.024241  0.021258  0.012393
#  42  0.044055  0.082990  0.016548  0.012143  0.006587 -0.000906 -0.001538
#  59  0.096197  0.106656  0.034116  0.027993  0.024249  0.017639  0.009006
#  27  0.035537  0.054918  0.015700  0.014000  0.012500  0.009933  0.005717
#  49  0.033999  0.045635  0.013814  0.012714  0.012516  0.010854  0.006252
#  77  0.097168  0.107118  0.027759  0.022729  0.017615  0.009391  0.004306
#  58  0.096638  0.118417  0.038614  0.030957  0.027915  0.023582  0.013059
#  33  0.024908  0.046810  0.014569  0.013151  0.011385  0.008799  0.005050
#  82  0.077493  0.095282  0.026029  0.022000  0.018127  0.011406  0.005788
#  60  0.034768  0.054421  0.023120  0.022025  0.025601  0.030214  0.019137
#  64  0.034860  0.050185  0.020120  0.019319  0.021228  0.023431  0.014565
#  80  0.090382  0.100211  0.029422  0.025092  0.021789  0.016023  0.008658
#  38  0.035070  0.052020  0.014690  0.012786  0.011357  0.007740  0.004110
#  30  0.060240  0.085771  0.031263  0.027582  0.024075  0.017846  0.009682
#  1   0.055307  0.102718  0.030971  0.028071  0.022913  0.014733  0.007862
#  53  0.110561  0.146104  0.032152  0.027714  0.017111  0.001197 -0.001158
#  22  0.037307  0.053475  0.018142  0.016306  0.014833  0.011592  0.006412
#  2   0.043619  0.132983  0.032895  0.026071  0.011389 -0.002110 -0.001779
#  24  0.061968  0.094602  0.025205  0.021214  0.016992  0.011953  0.006469
#  81  0.109584  0.117075  0.028774  0.022790  0.016363  0.006274  0.002078
#  75  0.088487  0.105261  0.028462  0.023786  0.019508  0.011730  0.005798
#  21  0.046231  0.071004  0.020941  0.018466  0.016775  0.014197  0.008264
#  61  0.038149  0.058208  0.024999  0.024048  0.027012  0.030656  0.019204
#  72  0.081451  0.106271  0.029200  0.024857  0.020254  0.012975  0.006713
#  14  0.065870  0.079842  0.026785  0.023627  0.022602  0.020901  0.012285
#  52  0.071360  0.080431  0.025040  0.021312  0.018592  0.013825  0.007499
#
#           865      1614      2202
#  5   0.104315 -0.050854 -0.050854
#  40  0.013344 -0.022580 -0.022580
#  32  0.079540 -0.028445 -0.028445
#  36  0.034400 -0.011385 -0.011385
#  46  0.102591 -0.023737 -0.023737
#  45  0.076057 -0.054907 -0.054907
#  17  0.091513 -0.088298 -0.088298
#  43  0.093956 -0.016798 -0.016798
#  35  0.054006 -0.012538 -0.012538
#  7   0.123600 -0.046959 -0.046959
#  50  0.077689 -0.050727 -0.050727
#  83  0.085698 -0.026618 -0.026618
#  20  0.100738 -0.011870 -0.011870
#  84  0.096347 -0.036799 -0.036799
#  26  0.127144 -0.028807 -0.028807
#  48 -0.023329 -0.038433 -0.038433
#  13  0.077989 -0.012602 -0.012602
#  25  0.132239 -0.015068 -0.015068
#  3   0.093178 -0.010254 -0.010254
#  18  0.037638 -0.060459 -0.060459
#  39  0.087056 -0.018090 -0.018090
#  8   0.143311  0.011630  0.011630
#  69  0.078742 -0.007350 -0.007350
#  6   0.146844 -0.091132 -0.091132
#  56  0.093704 -0.077609 -0.077609
#  37  0.008372 -0.028470 -0.028470
#  78  0.081546 -0.038039 -0.038039
#  86  0.076086 -0.053846 -0.053846
#  44  0.058059 -0.051349 -0.051349
#  51  0.068602 -0.007491 -0.007491
#  47  0.097511 -0.040870 -0.040870
#  85  0.072883 -0.040627 -0.040627
#  15  0.115433 -0.070703 -0.070703
#  70  0.123200 -0.011402 -0.011402
#  28  0.121543 -0.026405 -0.026405
#  42 -0.013000 -0.026132 -0.026132
#  59  0.086670 -0.066039 -0.066039
#  27  0.054772 -0.018784 -0.018784
#  49  0.036017 -0.035992 -0.035992
#  77  0.091884 -0.024327 -0.024327
#  58  0.099385 -0.082656 -0.082656
#  33  0.051618 -0.019339 -0.019339
#  82  0.110150 -0.022848 -0.022848
#  60  0.233464 -0.035043 -0.035043
#  64  0.175775 -0.017993 -0.017993
#  80  0.127488 -0.020553 -0.020553
#  38  0.025506 -0.018281 -0.018281
#  30  0.113617 -0.023462 -0.023462
#  1   0.151150 -0.006547 -0.006547
#  53  0.125428 -0.058359 -0.058359
#  22  0.042094 -0.043056 -0.043056
#  2   0.089411 -0.037687 -0.037687
#  24  0.080278 -0.030593 -0.030593
#  81  0.084970 -0.032187 -0.032187
#  75  0.104672 -0.029169 -0.029169
#  21  0.077161 -0.012196 -0.012196
#  61  0.190609 -0.028008 -0.028008
#  72  0.128333 -0.020541 -0.020541
#  14  0.133444 -0.026620 -0.026620
#  52  0.099457 -0.029959 -0.029959  ,
#  'y_train': 5      0.0000
#  40    14.5110
#  32    30.0612
#  36    19.8312
#  46    23.0911
#  45    30.8769
#  17     0.0000
#  43    27.4702
#  35    15.3606
#  7      1.3093
#  50    24.6842
#  83    22.0054
#  20    39.4862
#  84    19.2982
#  26     5.2748
#  48    12.4463
#  13    14.1771
#  25     4.0186
#  3      2.5432
#  18    29.8693
#  39    29.1406
#  8      0.0000
#  69    10.8025
#  6      1.3283
#  56    22.5388
#  37    34.7361
#  78    19.1441
#  86    29.9052
#  44    36.0649
#  51    40.0916
#  47    48.9077
#  85    23.2801
#  15    31.2564
#  70     7.6742
#  28    35.6804
#  42    24.4938
#  59    38.9125
#  27    25.4582
#  49    16.6815
#  77    10.0110
#  58    61.1292
#  33    26.9078
#  82    19.5382
#  60    34.0180
#  64    29.3177
#  80    20.6420
#  38    17.7963
#  30    21.0748
#  1      2.5181
#  53    15.1776
#  22    18.6587
#  2      3.8851
#  24     7.8264
#  81    20.6420
#  75    18.1328
#  21    21.1962
#  61    33.2116
#  72     3.8716
#  14     9.1983
#  52    23.3815
#  Name: Silt, dtype: float64,
#  'y_trainP': array([[-4.84659956],
#         [17.68808451],
#         [19.45444291],
#         [21.06520948],
#         [22.51979844],
#         [30.43204741],
#         [33.26679199],
#         [18.61222651],
#         [22.40899605],
#         [ 0.32196393],
#         [27.42246574],
#         [19.23519059],
#         [23.77626859],
#         [22.11005105],
#         [20.66962046],
#         [23.06349682],
#         [18.71433809],
#         [16.36753724],
#         [13.44050132],
#         [32.60365431],
#         [20.65270062],
#         [13.73296378],
#         [16.34219573],
#         [-2.94944111],
#         [26.57274031],
#         [21.45713894],
#         [25.38975253],
#         [26.08427893],
#         [26.30657739],
#         [16.53864765],
#         [25.42009459],
#         [20.68512376],
#         [34.50449563],
#         [15.74381742],
#         [26.34110419],
#         [17.14311323],
#         [33.41853091],
#         [19.65597321],
#         [25.5874445 ],
#         [20.36967614],
#         [39.76932   ],
#         [17.67261536],
#         [18.21034127],
#         [22.84832726],
#         [19.85842282],
#         [21.66980019],
#         [20.58726522],
#         [20.2812306 ],
#         [ 9.73797007],
#         [12.88155339],
#         [25.56419156],
#         [ 0.74485993],
#         [21.10514769],
#         [20.30348396],
#         [20.7866978 ],
#         [20.56326031],
#         [26.34689804],
#         [17.007963  ],
#         [24.74642127],
#         [22.537816  ]]),
#  'iqrp_test': 1.6266149845966027,
#  'r2_test': 0.36660704602618444,
#  'rpd_test': 1.2813862389788009,
#  'r2_train': 0.3918227475740702,
#  'L1y_testP': 0      9.468396
#  1      8.390535
#  2      1.217369
#  3     12.919206
#  4     10.594469
#          ...
#  82    17.160201
#  83    16.924024
#  84    20.603770
#  85    19.564025
#  86    25.013731
#  Name: Silt, Length: 86, dtype: float64,
#  'L1y_test': 0      0.0000
#  1      2.5181
#  2      3.8851
#  3      2.5432
#  4      5.2072
#         ...
#  82    19.5382
#  83    22.0054
#  84    19.2982
#  85    23.2801
#  86    29.9052
#  Name: Silt, Length: 86, dtype: float64,
#  'L1iqrp_test': 1.6818111362425483,
#  'L1r2_test': 0.3153496663027723,
#  'L1rpd_test': 1.2156410323271545}

# %% [markdown]
# ##  Sand Models

# %% [markdown]
# ### Cubist

# %% [markdown]
# Sand -> [ r2 - **0.52**, Spec - fod2, n_bands -10]     <br/><br/>
# ***Description***: To obtain the best model for sand using cubist method we trained the model on the first order derivative of the smoothed spectra resampled to the 10 bands provided by Sentinel.

# %%
sand_model_cubist = Cubist(n_committees = 15, n_rules = 10) 
sand_model_cubist.fit(fod_sampled10,  T[0])
# Out:
# Cubist(n_committees=15, n_rules=10)

# %%
feature_scores['Sand'] = permutation_importance(sand_model_cubist, fod_sampled10, T[0], n_repeats=20, random_state=0)

# %%
model_details['Sand'] = {'method': 'cubist', 'spec': fod_sampled10, 'spec_proc': 'fod2', 'n_bands': 10}
show_important_features_for ('Sand', model_details, feature_scores, 3, 20, 2)

# %% [markdown]
# Sand -> [ r2 - **0.5**, Spec - fod2, n_bands -10]     <br/><br/>
# ***Description***: To obtain the best model for sand using plsr method we trained the model on the first order derivative of the smoothed spectra resampled to the 10 bands provided by Sentinel.

# %%
sand_model_plsr = PLSRegression(n_components=4, scale=True) 
sand_model_plsr.fit(fod_sampled10,  T[0])
# Out:
# PLSRegression(n_components=4)

# %%
feature_scores['Sand'] = permutation_importance(sand_model_plsr, fod_sampled10, T[0], n_repeats=20, random_state=0)

# %%
model_details['Sand'] = {'method': 'plsr', 'spec': fod_sampled10, 'spec_proc': 'fod2', 'n_bands': 10}
show_important_features_for ('Sand', model_details, feature_scores, 4, 20, 20)

# %% [markdown]
# ##  Silt

# %% [markdown]
# ### PLSR

# %% [markdown]
# Silt -> [ r2 - **0.32**, Spec - fod2, n_bands - 10]   <br/><br/>
# ***Description***:To obtain the best model for silt using plsr method we trained the model on the
#  first order derivative of the smoothed spectra resampled to the 10 bands provided by Sentinel.

# %%
silt_model_plsr = PLSRegression(n_components=4, scale=True)  
silt_model_plsr.fit(fod_sampled10,  T[1])
# Out:
# PLSRegression(n_components=4)

# %%
feature_scores['Silt'] = permutation_importance(silt_model_plsr, fod_sampled10, T[1], n_repeats=20, random_state=0)

# %%
model_details['Silt'] = {'method': 'plsr', 'spec': fod_sampled10, 'spec_proc': 'fod2', 'n_bands': 10}
show_important_features_for ('Silt', model_details, feature_scores, 6, 20, 2)

# %%
# Out:
# {'bp': {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50},
#  'X_test':          493       560       665       704       741       783       833  \
#  76  0.092232  0.103406  0.028157  0.023571  0.019460  0.012313  0.006098
#  0   0.049058  0.096656  0.028886  0.025786  0.020817  0.013582  0.007529
#  71  0.086641  0.100433  0.028638  0.024143  0.020397  0.013197  0.006692
#  23  0.029648  0.050024  0.016800  0.015429  0.014238  0.012487  0.007146
#  12  0.067791  0.094045  0.026367  0.023286  0.020159  0.015354  0.008502
#  57  0.150195  0.130608  0.035249  0.026286  0.016875  0.004678  0.000769
#  10  0.139684  0.132174  0.034654  0.028637  0.023852  0.013907  0.006707
#  19  0.047998  0.065271  0.026044  0.022986  0.022804  0.022374  0.013425
#  4   0.051135  0.071463  0.015638  0.013071  0.006246 -0.002937 -0.002652
#  68  0.147134  0.137698  0.031841  0.024224  0.014960  0.002803 -0.000143
#  62  0.033641  0.051815  0.022151  0.021350  0.023705  0.026805  0.016804
#  65  0.036477  0.045267  0.018225  0.016797  0.017811  0.018188  0.010950
#  54  0.093176  0.114595  0.030791  0.025939  0.022793  0.019663  0.011363
#  74  0.089411  0.112190  0.030205  0.025357  0.020294  0.012085  0.005842
#  63  0.032808  0.052435  0.022753  0.022224  0.025367  0.029826  0.018964
#  67  0.121970  0.087031  0.028305  0.026214  0.011937 -0.008443 -0.007529
#  34  0.034741  0.067205  0.016439  0.013927  0.011003  0.006726  0.003569
#  79  0.095474  0.109878  0.031281  0.026142  0.021430  0.013838  0.007042
#  55  0.108625  0.107114  0.038798  0.034627  0.026810  0.014692  0.006830
#  73  0.094108  0.113235  0.030000  0.024714  0.019563  0.010790  0.005083
#  11  0.080415  0.094832  0.033011  0.026123  0.024515  0.020975  0.011686
#  31  0.030204  0.066459  0.018727  0.016107  0.011737  0.006667  0.003638
#  41  0.048330  0.082643  0.016605  0.012000  0.006651 -0.000328 -0.001244
#  29  0.034552  0.062198  0.016308  0.014224  0.011992  0.007951  0.004192
#  9   0.045763  0.068669  0.025067  0.023286  0.022937  0.021259  0.012619
#  66  0.132233  0.154637  0.032784  0.025102  0.015319  0.002261 -0.000382
#
#           865      1614      2202
#  76  0.114333 -0.025754 -0.025754
#  0   0.138300 -0.008829 -0.008829
#  71  0.114622 -0.021662 -0.021662
#  23  0.057378 -0.026632 -0.026632
#  12  0.093033 -0.007690 -0.007690
#  57  0.082905 -0.063328 -0.063328
#  10  0.190898 -0.025712 -0.025712
#  19  0.125722 -0.043168 -0.043168
#  4   0.008144 -0.008703 -0.008703
#  68  0.080610 -0.044447 -0.044447
#  62  0.213467 -0.000682 -0.000682
#  65  0.097412 -0.033544 -0.033544
#  54  0.123836 -0.033381 -0.033381
#  74  0.116906 -0.032935 -0.032935
#  63  0.265052  0.010577  0.010577
#  67  0.076717 -0.157731 -0.157731
#  34  0.032171 -0.013475 -0.013475
#  79  0.116243 -0.023604 -0.023604
#  55  0.125490 -0.107168 -0.107168
#  73  0.105917 -0.031141 -0.031141
#  11  0.115826 -0.095666 -0.095666
#  31  0.064161 -0.021936 -0.021936
#  41 -0.012150 -0.024443 -0.024443
#  29  0.021931 -0.018614 -0.018614
#  9   0.160100 -0.001769 -0.001769
#  66  0.046001 -0.075084 -0.075084  ,
#  'y_test': 76     8.9723
#  0      0.0000
#  71    14.2341
#  23    24.4512
#  12    22.9545
#  57    33.6265
#  10     0.0000
#  19    18.2735
#  4      5.2072
#  68    13.9464
#  62    25.2226
#  65    31.5720
#  54    30.9949
#  74    12.9789
#  63    21.1082
#  67    33.8895
#  34    18.7831
#  79    11.4461
#  55    59.6906
#  73    12.8932
#  11    44.8908
#  31    40.3139
#  41    27.0416
#  29    16.6168
#  9      2.5176
#  66    29.8678
#  Name: Silt, dtype: float64,
#  'y_testP': array([16.2431673 ,  6.5848792 , 19.31108305, 21.79234242, 20.48871521,
#         23.19997384,  9.7035775 , 19.72637439, 15.4183253 , 20.27410075,
#         25.57021467, 20.96427147, 23.5398688 , 19.36361964, 31.98034525,
#         18.21781588, 19.37905415, 18.41791047, 38.56924041, 18.02785658,
#         25.43264202, 22.69150946, 21.3554994 , 19.63587455, 10.36568555,
#         23.02742307]),
#  'X_train':          493       560       665       704       741       783       833  \
#  5   0.046460  0.156603  0.039449  0.031661  0.012187 -0.005600 -0.004053
#  40  0.054197  0.086247  0.017829  0.013643  0.008540  0.001687  0.000202
#  32  0.024743  0.051282  0.018124  0.016985  0.015640  0.013236  0.007738
#  36  0.034964  0.042586  0.013288  0.011925  0.011624  0.009579  0.005303
#  46  0.092337  0.135907  0.032627  0.025915  0.020892  0.014499  0.007824
#  45  0.093726  0.123704  0.033276  0.026844  0.021885  0.015165  0.008039
#  17  0.046142  0.055871  0.025041  0.021587  0.020156  0.018315  0.010600
#  43  0.075302  0.131206  0.028429  0.022071  0.017278  0.011665  0.006458
#  35  0.042804  0.053430  0.017120  0.015492  0.015093  0.012836  0.007279
#  7   0.086823  0.225231  0.046462  0.036000  0.016071 -0.001750 -0.001650
#  50  0.064063  0.091500  0.026357  0.022500  0.019476  0.014859  0.008208
#  83  0.113055  0.117952  0.028188  0.021848  0.015664  0.005365  0.001435
#  20  0.090528  0.113165  0.031276  0.026619  0.022857  0.017155  0.009498
#  84  0.110522  0.131313  0.034642  0.027945  0.020859  0.010340  0.004493
#  26  0.041275  0.071224  0.022743  0.020857  0.019667  0.018256  0.010877
#  48  0.022819  0.036960  0.010681  0.009218  0.007182  0.003012  0.001000
#  13  0.033266  0.047655  0.015648  0.014643  0.014198  0.012569  0.007275
#  25  0.041256  0.072933  0.021781  0.019714  0.018071  0.016260  0.009690
#  3   0.042079  0.088727  0.026924  0.024143  0.019389  0.012284  0.006627
#  18  0.055661  0.076074  0.026678  0.023148  0.020599  0.015751  0.008605
#  39  0.036174  0.047129  0.015400  0.014357  0.014421  0.013895  0.008327
#  8   0.128079  0.158365  0.034114  0.027857  0.021373  0.011075  0.005281
#  69  0.063371  0.077218  0.021040  0.017406  0.014286  0.008847  0.004416
#  6   0.048663  0.171193  0.045076  0.036571  0.015952 -0.003782 -0.002885
#  56  0.098345  0.086726  0.026837  0.020888  0.015297  0.007524  0.002969
#  37  0.017866  0.019453  0.007186  0.007143  0.006905  0.005426  0.002890
#  78  0.102184  0.118901  0.031937  0.025361  0.020102  0.011774  0.005608
#  86  0.130544  0.137226  0.034416  0.027646  0.019056  0.007035  0.002426
#  44  0.089285  0.128790  0.029369  0.022237  0.016586  0.009140  0.004390
#  51  0.020864  0.032539  0.010026  0.009768  0.009951  0.009960  0.006103
#  47  0.075180  0.113182  0.030200  0.024571  0.020817  0.015986  0.008725
#  85  0.110561  0.123577  0.030151  0.023304  0.016031  0.004574  0.000848
#  15  0.042487  0.063398  0.029276  0.026615  0.026966  0.026271  0.015445
#  70  0.065808  0.078110  0.023638  0.020429  0.017889  0.012650  0.006762
#  28  0.073376  0.096446  0.029461  0.026143  0.024241  0.021258  0.012393
#  42  0.044055  0.082990  0.016548  0.012143  0.006587 -0.000906 -0.001538
#  59  0.096197  0.106656  0.034116  0.027993  0.024249  0.017639  0.009006
#  27  0.035537  0.054918  0.015700  0.014000  0.012500  0.009933  0.005717
#  49  0.033999  0.045635  0.013814  0.012714  0.012516  0.010854  0.006252
#  77  0.097168  0.107118  0.027759  0.022729  0.017615  0.009391  0.004306
#  58  0.096638  0.118417  0.038614  0.030957  0.027915  0.023582  0.013059
#  33  0.024908  0.046810  0.014569  0.013151  0.011385  0.008799  0.005050
#  82  0.077493  0.095282  0.026029  0.022000  0.018127  0.011406  0.005788
#  60  0.034768  0.054421  0.023120  0.022025  0.025601  0.030214  0.019137
#  64  0.034860  0.050185  0.020120  0.019319  0.021228  0.023431  0.014565
#  80  0.090382  0.100211  0.029422  0.025092  0.021789  0.016023  0.008658
#  38  0.035070  0.052020  0.014690  0.012786  0.011357  0.007740  0.004110
#  30  0.060240  0.085771  0.031263  0.027582  0.024075  0.017846  0.009682
#  1   0.055307  0.102718  0.030971  0.028071  0.022913  0.014733  0.007862
#  53  0.110561  0.146104  0.032152  0.027714  0.017111  0.001197 -0.001158
#  22  0.037307  0.053475  0.018142  0.016306  0.014833  0.011592  0.006412
#  2   0.043619  0.132983  0.032895  0.026071  0.011389 -0.002110 -0.001779
#  24  0.061968  0.094602  0.025205  0.021214  0.016992  0.011953  0.006469
#  81  0.109584  0.117075  0.028774  0.022790  0.016363  0.006274  0.002078
#  75  0.088487  0.105261  0.028462  0.023786  0.019508  0.011730  0.005798
#  21  0.046231  0.071004  0.020941  0.018466  0.016775  0.014197  0.008264
#  61  0.038149  0.058208  0.024999  0.024048  0.027012  0.030656  0.019204
#  72  0.081451  0.106271  0.029200  0.024857  0.020254  0.012975  0.006713
#  14  0.065870  0.079842  0.026785  0.023627  0.022602  0.020901  0.012285
#  52  0.071360  0.080431  0.025040  0.021312  0.018592  0.013825  0.007499
#
#           865      1614      2202
#  5   0.104315 -0.050854 -0.050854
#  40  0.013344 -0.022580 -0.022580
#  32  0.079540 -0.028445 -0.028445
#  36  0.034400 -0.011385 -0.011385
#  46  0.102591 -0.023737 -0.023737
#  45  0.076057 -0.054907 -0.054907
#  17  0.091513 -0.088298 -0.088298
#  43  0.093956 -0.016798 -0.016798
#  35  0.054006 -0.012538 -0.012538
#  7   0.123600 -0.046959 -0.046959
#  50  0.077689 -0.050727 -0.050727
#  83  0.085698 -0.026618 -0.026618
#  20  0.100738 -0.011870 -0.011870
#  84  0.096347 -0.036799 -0.036799
#  26  0.127144 -0.028807 -0.028807
#  48 -0.023329 -0.038433 -0.038433
#  13  0.077989 -0.012602 -0.012602
#  25  0.132239 -0.015068 -0.015068
#  3   0.093178 -0.010254 -0.010254
#  18  0.037638 -0.060459 -0.060459
#  39  0.087056 -0.018090 -0.018090
#  8   0.143311  0.011630  0.011630
#  69  0.078742 -0.007350 -0.007350
#  6   0.146844 -0.091132 -0.091132
#  56  0.093704 -0.077609 -0.077609
#  37  0.008372 -0.028470 -0.028470
#  78  0.081546 -0.038039 -0.038039
#  86  0.076086 -0.053846 -0.053846
#  44  0.058059 -0.051349 -0.051349
#  51  0.068602 -0.007491 -0.007491
#  47  0.097511 -0.040870 -0.040870
#  85  0.072883 -0.040627 -0.040627
#  15  0.115433 -0.070703 -0.070703
#  70  0.123200 -0.011402 -0.011402
#  28  0.121543 -0.026405 -0.026405
#  42 -0.013000 -0.026132 -0.026132
#  59  0.086670 -0.066039 -0.066039
#  27  0.054772 -0.018784 -0.018784
#  49  0.036017 -0.035992 -0.035992
#  77  0.091884 -0.024327 -0.024327
#  58  0.099385 -0.082656 -0.082656
#  33  0.051618 -0.019339 -0.019339
#  82  0.110150 -0.022848 -0.022848
#  60  0.233464 -0.035043 -0.035043
#  64  0.175775 -0.017993 -0.017993
#  80  0.127488 -0.020553 -0.020553
#  38  0.025506 -0.018281 -0.018281
#  30  0.113617 -0.023462 -0.023462
#  1   0.151150 -0.006547 -0.006547
#  53  0.125428 -0.058359 -0.058359
#  22  0.042094 -0.043056 -0.043056
#  2   0.089411 -0.037687 -0.037687
#  24  0.080278 -0.030593 -0.030593
#  81  0.084970 -0.032187 -0.032187
#  75  0.104672 -0.029169 -0.029169
#  21  0.077161 -0.012196 -0.012196
#  61  0.190609 -0.028008 -0.028008
#  72  0.128333 -0.020541 -0.020541
#  14  0.133444 -0.026620 -0.026620
#  52  0.099457 -0.029959 -0.029959  ,
#  'y_train': 5      0.0000
#  40    14.5110
#  32    30.0612
#  36    19.8312
#  46    23.0911
#  45    30.8769
#  17     0.0000
#  43    27.4702
#  35    15.3606
#  7      1.3093
#  50    24.6842
#  83    22.0054
#  20    39.4862
#  84    19.2982
#  26     5.2748
#  48    12.4463
#  13    14.1771
#  25     4.0186
#  3      2.5432
#  18    29.8693
#  39    29.1406
#  8      0.0000
#  69    10.8025
#  6      1.3283
#  56    22.5388
#  37    34.7361
#  78    19.1441
#  86    29.9052
#  44    36.0649
#  51    40.0916
#  47    48.9077
#  85    23.2801
#  15    31.2564
#  70     7.6742
#  28    35.6804
#  42    24.4938
#  59    38.9125
#  27    25.4582
#  49    16.6815
#  77    10.0110
#  58    61.1292
#  33    26.9078
#  82    19.5382
#  60    34.0180
#  64    29.3177
#  80    20.6420
#  38    17.7963
#  30    21.0748
#  1      2.5181
#  53    15.1776
#  22    18.6587
#  2      3.8851
#  24     7.8264
#  81    20.6420
#  75    18.1328
#  21    21.1962
#  61    33.2116
#  72     3.8716
#  14     9.1983
#  52    23.3815
#  Name: Silt, dtype: float64,
#  'y_trainP': array([ 1.03953411, 15.28364736, 27.26380685, 19.65213114, 25.19877851,
#         32.79072477,  3.89316712, 23.71446785, 16.9924798 ,  3.64822032,
#         24.11659068, 20.81703867, 38.09480411, 20.73129754,  7.02956896,
#         15.17366503, 16.09199113,  6.24124767,  5.43656914, 27.63591145,
#         26.36110501,  1.85763447, 13.25110151,  1.67405009, 21.95198539,
#         33.40035311, 19.4325101 , 27.02385295, 31.21219122, 38.39978914,
#         43.41759747, 23.65915164, 30.2853455 ,  6.93185353, 35.15983503,
#         21.3554994 , 40.1731085 , 22.88465038, 18.80060947, 15.6250189 ,
#         58.17000047, 24.38464488, 17.59055114, 32.92297316, 28.61053727,
#         18.62057336, 19.2051352 , 21.25636581,  2.68242734, 14.59673047,
#         19.70136132,  5.5728612 , 12.29966723, 20.16663005, 17.09957927,
#         20.89097197, 32.48215515,  6.92381178, 11.55150716, 22.11523071]),
#  'iqrp_test': 1.877187200732929,
#  'r2_test': 0.5244156043370891,
#  'rpd_test': 1.4787776270257624,
#  'r2_train': 0.969604772073304,
#  'L1y_testP': 0      5.823168
#  1      2.846201
#  2     17.120377
#  3     13.576963
#  4     22.043243
#          ...
#  82    10.790655
#  83    20.025675
#  84    27.936580
#  85    21.980634
#  86    25.017862
#  Name: Silt, Length: 86, dtype: float64,
#  'L1y_test': 0      0.0000
#  1      2.5181
#  2      3.8851
#  3      2.5432
#  4      5.2072
#         ...
#  82    19.5382
#  83    22.0054
#  84    19.2982
#  85    23.2801
#  86    29.9052
#  Name: Silt, Length: 86, dtype: float64,
#  'L1iqrp_test': 1.8131052252737188,
#  'L1r2_test': 0.4109159650543517,
#  'L1rpd_test': 1.3105425813113605}

# %% [markdown]
# ### Gradient Boosting Regression Tree

# %% [markdown]
# Silt -> [ r2 - **0.41**, Spec - fod2, n_bands - 10]   <br/><br/>
# ***Description***:To obtain the best model for silt using gbrt method we trained the model on the first order derivative of the smoothed spectra resampled to the 10 bands provided by Sentinel.

# %%
silt_model_gbrt = GradientBoostingRegressor(learning_rate = 0.1, max_depth = 3, n_estimators = 50, random_state = 42)  
silt_model_gbrt.fit(fod_sampled10,  T[1])
# Out:
# GradientBoostingRegressor(n_estimators=50, random_state=42)

# %%
feature_scores['Silt'] = permutation_importance(silt_model_gbrt, fod_sampled10, T[1], n_repeats=20, random_state=0)

# %%
model_details['Silt'] = {'method': 'gbrt', 'spec': fod_sampled10, 'spec_proc': 'fod2', 'n_bands': 10}
show_important_features_for ('Silt', model_details, feature_scores, 5, 20, 2)

# %% [markdown]
# ## Clay

# %%
HMtreeSenNew['plsr']['CaCO3']['none']['none']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19108\1766851581.py in <module>
# ----> 1 HMtreeSenNew['plsr']['CaCO3']['none']['none']
#
# NameError: name 'HMtreeSenNew' is not defined

# %% [markdown]
# ### PLSR

# %% [markdown]
# Clay -> [ r2 - **0.61**, Spec - log, n_bands - 10]   <br/><br/>
# ***Description***:To obtain the best model for clay using plsr method we trained the model on the logarithmic of the reflectance inverse of the spectra and resampled it to the 10 bands provided by Sentinel.

# %%
clay_model_plsr = PLSRegression(n_components=4, scale=True)  
clay_model_plsr.fit(sampled_log10,  T[2])
# Out:
# PLSRegression(n_components=4)

# %%
feature_scores['Clay'] = permutation_importance(clay_model_plsr, sampled_log10, T[2], n_repeats=20, random_state=0)

# %%
model_details['Clay'] = {'method': 'plsr', 'spec': sampled_log10, 'spec_proc': 'log', 'n_bands': 10}
show_important_features_for ('Clay', model_details, feature_scores, 0.2, 1, 2)

# %% [markdown]
# ### Kernel Ridge

# %% [markdown]
# Clay -> [ r2 - **0.58**, Spec - log, n_bands - 10]   <br/><br/>
# ***Description***:To obtain the best model for clay using kernel ridge regression method we trained the model on the logarithmic of the reflectance inverse of the spectra and resampled it to the 10 bands provided by Sentinel.

# %%
clay_model_kernelridge = KernelRidge(alpha = 0.001) 
clay_model_kernelridge.fit(sampled_log10,  T[2])
# Out:
# KernelRidge(alpha=0.001)

# %%
feature_scores['Clay'] = permutation_importance(clay_model_kernelridge, sampled_log10, T[2], n_repeats=20, random_state=0)

# %%
model_details['Clay'] = {'method': 'ridge', 'spec': sampled_log10, 'spec_proc': 'log', 'n_bands': 10}
show_important_features_for ('Clay', model_details, feature_scores, 0.05, 1, 2)

# %% [markdown]
# ## TOC

# %% [markdown]
# ### Cubist

# %% [markdown]
# TOC -> [ r2 - **0.41**, Spec - log, n_bands - 10]   <br/><br/>
# ***Description***:To obtain the best model for TOC using cubist method we trained the model on the logarithmic of the reflectance inverse of the spectra and is resampled to the 10 bands provided by Sentinel.

# %%
TOC_model_cubist = Cubist(n_committees = 10, n_rules = 10)
TOC_model_cubist.fit(sampled_log10,  T[3])
# Out:
# Cubist(n_committees=10, n_rules=10)

# %%
feature_scores['TOC'] = permutation_importance(TOC_model_cubist, sampled_log10, T[3], n_repeats=20, random_state=0)
model_details['TOC'] = {'method': 'cubist', 'spec': sampled_log10, 'spec_proc': 'log', 'n_bands': 10}
show_important_features_for ('TOC', model_details, feature_scores, 2, 1, 2)

# %% [markdown]
# ### Gradient Boosting Regression Tree

# %% [markdown]
# TOC -> [ r2 - **0.49**, Spec - cr, n_bands - 10]   <br/><br/>
# ***Description***:To obtain the best model for TOC using gbrt method we trained the model on the continuum removal of the smoothed spectra and it is resampled to the 10 bands provided by Sentinel.

# %%
TOC_model_gbrt = GradientBoostingRegressor(learning_rate = 0.1, max_depth = 4, n_estimators = 30, random_state = 42)
TOC_model_gbrt.fit(sampled_cr10,  T[3])
# Out:
# GradientBoostingRegressor(max_depth=4, n_estimators=30, random_state=42)

# %%
feature_scores['TOC'] = permutation_importance(TOC_model_gbrt, sampled_cr10, T[3], n_repeats=20, random_state=0)

# %%
model_details['TOC'] = {'method': 'gbrt', 'spec': sampled_cr10, 'spec_proc': 'cr', 'n_bands': 10}
show_important_features_for ('TOC', model_details, feature_scores, 4, 20, 2)

# %% [markdown]
# ## CaCO3

# %% [markdown]
# ### PLSR

# %% [markdown]
# CaCO3 -> [ r2 - **0.63**, Spec - none, n_bands - 10]   <br/><br/>
# ***Description***:To obtain the best model for CaCO3 using plsr method we trained the model on the smoothed spectra which is resampled to the 10 bands provided by Sentinel.

# %%
CaCO3_model_plsr = PLSRegression(n_components=4, scale=True)
CaCO3_model_plsr.fit(sampled_spec10,  T[4])
# Out:
# PLSRegression(n_components=4)

# %%
feature_scores['CaCO3'] = permutation_importance(CaCO3_model_plsr, sampled_spec[10], T[4], n_repeats=20, random_state=0)
model_details['CaCO3'] = {'method': 'plsr', 'spec': sampled_spec[10], 'spec_proc': 'none', 'n_bands': 10}
show_important_features_for ('CaCO3', model_details, feature_scores, 0.2, 8, 2)

# %% [markdown]
# ### SVR

# %% [markdown]
# #### Train test

# %% [markdown]
# CaCO3 -> [ r2 - **0.62**, Spec - log, n_bands - 100]   <br/><br/>
# ***Description***:To obtain the best model for CaCO3 using svr method we trained the model on the logarithmic of the reflectance inverse of the spectra which is resampled to 100 bands.

# %%
CaCO3_model_svr = SVR(C = 10, gamma = 0.01, kernel = 'linear')
CaCO3_model_svr.fit(sampled_log[100],  T[4])
# Out:
# SVR(C=10, gamma=0.01, kernel='linear')

# %%
feature_scores['CaCO3'] = permutation_importance(CaCO3_model_svr, sampled_log[100], T[4], n_repeats=10, random_state=0)
model_details['CaCO3'] = {'method': 'svr', 'spec': sampled_log[100], 'spec_proc': 'log', 'n_bands': 100}
show_important_features_for ('CaCO3', model_details, feature_scores, 130, 13, 2)

# %% [markdown]
# #### Leave one out

# %% [markdown]
# CaCO3 -> [ r2 - **0.58**, Spec - log, n_bands - 100]   <br/><br/>
# ***Description***:To obtain the best model for CaCO3 using svr method we trained the model on the logarithmic of the reflectance inverse of the spectra which is resampled to 100 bands.

# %%
CaCO3_model_svr = SVR(C = 10, gamma = 0.01, kernel = 'linear')
CaCO3_model_svr.fit(sampled_log[100],  T[4])
# Out:
# SVR(C=10, gamma=0.01, kernel='linear')

# %%
feature_scores['CaCO3'] = permutation_importance(CaCO3_model_svr, sampled_log[100], T[4], n_repeats=10, random_state=0)
model_details['CaCO3'] = {'method': 'svr', 'spec': sampled_log[100], 'spec_proc': 'log', 'n_bands': 100}
show_important_features_for ('CaCO3', model_details, feature_scores, 120, 12, 2)

# %% [markdown]
# ### Kernel Ridge

# %% [markdown]
# #### Train test

# %% [markdown]
# CaCO3 -> [ r2 - **0.65**, Spec -none, n_bands - 9]   <br/><br/>
# ***Description***:To obtain the best model for CaCO3 using kernel ridge regression method method we trained the model on the smoothed spectra which is resampled to 9 bands.

# %%
CaCO3_model_kernelridge = KernelRidge(alpha = 0.002) 
CaCO3_model_kernelridge.fit(sampled_spec[9],  T[4])
# Out:
# KernelRidge(alpha=0.002)

# %%
feature_scores['CaCO3'] = permutation_importance(CaCO3_model_kernelridge, sampled_spec[9], T[4], n_repeats=10, random_state=0)
model_details['CaCO3'] = {'method': 'ridge', 'spec': sampled_spec[9], 'spec_proc': 'none', 'n_bands': 9}
show_important_features_for ('CaCO3', model_details, feature_scores, 0.06, 6, 2)

# %% [markdown]
# #### Leave one out

# %% [markdown]
# CaCO3 -> [ r2 - **0.59**, Spec - log, n_bands - 70]   <br/><br/>
# ***Description***:To obtain the best model for CaCO3 using kernel ridge regression method we trained the model on the logarithmic of the reflectance inverse of the spectra which is resampled to 70 bands.

# %%
CaCO3_model_kernelridge = KernelRidge(alpha = 0.05) 
CaCO3_model_kernelridge.fit(sampled_log[70],  T[4])
# Out:
# KernelRidge(alpha=0.05)

# %%
feature_scores['CaCO3'] = permutation_importance(CaCO3_model_kernelridge, sampled_log[70], T[4], n_repeats=10, random_state=0)
model_details['CaCO3'] = {'method': 'ridge', 'spec': sampled_log[70], 'spec_proc': 'log', 'n_bands': 70}
show_important_features_for ('CaCO3', model_details, feature_scores, 3, 10, 2)

# %% [markdown]
# ### Cubist

# %% [markdown]
# #### Train test

# %% [markdown]
# CaCO3 -> [ r2 - **0.69**, Spec - fod2, n_bands - 60]   <br/><br/>
# ***Description***:To obtain the best model for CaCO3 using cubist method we trained the model on the first order derivative of the smoothed spectra which is resampled to 60 bands.

# %%
CaCO3_model_cubist = Cubist(n_committees = 5, n_rules = 10)
CaCO3_model_cubist.fit(fod_sampled[60],  T[4])
# Out:
# Cubist(n_committees=5, n_rules=10)

# %%
feature_scores['CaCO3'] = permutation_importance(CaCO3_model_cubist, fod_sampled[60], T[4], n_repeats=10, random_state=0)
model_details['CaCO3'] = {'method': 'cubist', 'spec': fod_sampled[60], 'spec_proc': 'fod2', 'n_bands': 60}
show_important_features_for ('CaCO3', model_details, feature_scores, 30, 400, 2)

# %% [markdown]
# #### Leave one out

# %% [markdown]
# CaCO3 -> [ r2 - **0.66**, Spec - fod2, n_bands - 27]   <br/><br/>
# ***Description***:To obtain the best model for CaCO3 using cubist method we trained the model on the first order derivative of the smoothed spectra which is resampled to 27 bands.

# %%
CaCO3_model_cubist =Cubist(n_committees = 10, n_rules = 10)
CaCO3_model_cubist.fit(fod_sampled[27],  T[4])
# Out:
# Cubist(n_committees=10, n_rules=10)

# %%
feature_scores['CaCO3'] = permutation_importance(CaCO3_model_cubist, fod_sampled[27], T[4], n_repeats=10, random_state=0)
model_details['CaCO3'] = {'method': 'cubist', 'spec': fod_sampled[27], 'spec_proc': 'fod2', 'n_bands': 27}
show_important_features_for ('CaCO3', model_details, feature_scores, 8, 100, 2)

# %% [markdown]
# ### Gradient Boosting Regression Tree

# %% [markdown]
# #### Train test

# %% [markdown]
# CaCO3 -> [ r2 - **0.59**, Spec - fod2, n_bands - 35]   <br/><br/>
# ***Description***:To obtain the best model for CaCO3 using gbrt method we trained the model on the first order derivative of the smoothed spectra which is resampled to 35 bands.

# %%
CaCO3_model_gbrt =GradientBoostingRegressor(learning_rate = 0.1, max_depth = 3, n_estimators = 50, random_state = 42)
CaCO3_model_gbrt.fit(fod_sampled[35],  T[4])
# Out:
# GradientBoostingRegressor(n_estimators=50, random_state=42)

# %%
feature_scores['CaCO3'] = permutation_importance(CaCO3_model_gbrt, fod_sampled[35], T[4], n_repeats=10, random_state=0)
model_details['CaCO3'] = {'method': 'gbrt', 'spec': fod_sampled[35], 'spec_proc': 'fod2', 'n_bands': 35}
show_important_features_for ('CaCO3', model_details, feature_scores, 10, 200, 2)

# %% [markdown]
# #### Leave one out

# %% [markdown]
# CaCO3 -> [ r2 - **0.66**, Spec - fod2, n_bands - 27]   <br/><br/>
# ***Description***:To obtain the best model for CaCO3 using gbrt method we trained the model on the first order derivative of the smoothed spectra which is resampled to 27 bands.

# %%
CaCO3_model_gbrt =GradientBoostingRegressor(learning_rate = 0.1, max_depth = 3, n_estimators = 50, random_state = 42)
CaCO3_model_gbrt.fit(fod_sampled[27],  T[4])
# Out:
# GradientBoostingRegressor(n_estimators=50, random_state=42)

# %%
feature_scores['CaCO3'] = permutation_importance(CaCO3_model_gbrt, fod_sampled[27], T[4], n_repeats=10, random_state=0)
model_details['CaCO3'] = {'method': 'gbrt', 'spec': fod_sampled[27], 'spec_proc': 'fod2', 'n_bands': 27}
show_important_features_for ('CaCO3', model_details, feature_scores, 8, 100, 2)
